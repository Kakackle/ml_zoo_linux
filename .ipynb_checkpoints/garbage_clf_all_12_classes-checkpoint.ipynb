# %% [markdown]
# # Garbage classification project pt.2
# Using all of the 12 classes, after establishing some baselines on just select 3 classes from the dataset

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow import keras

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import random
import os
# Out:
# 2024-03-22 21:24:17.130829: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-22 21:24:19.042242: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/user/miniconda3/envs/tf/lib
# 2024-03-22 21:24:19.042342: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/user/miniconda3/envs/tf/lib
# 2024-03-22 21:24:19.042349: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# ## Downloading the dataset

# %%
# !wget -L "https://drive.google.com/uc?export=download&id=1qoFPTgm4bqfS2kx0luMkMgUs7fKrk376"

# %%
# !gdown "https://drive.google.com/uc?export=download&id=1qoFPTgm4bqfS2kx0luMkMgUs7fKrk376"

# %%
# %%time
# !unrar x -idp garbage_classification.rar

# %%
# !ls garbage_classification
# Out:
# /bin/bash: /home/user/miniconda3/envs/tf/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# battery     brown-glass  clothes      metal  plastic  trash
# biological  cardboard	 green-glass  paper  shoes    white-glass

# %% [markdown]
# ## Random seed

# %%
tf.random.set_seed(1337)

# %% [markdown]
# ## Loading the dataset from files

# %%
ds_folder = "garbage_classification"

# %%
image_size = (256, 256)
batch_size = 32

# %%
train_ds, val_ds = keras.utils.image_dataset_from_directory(
    directory = f"{ds_folder}",
    labels = "inferred",
    color_mode = "rgb",
    subset="both",
    validation_split=0.2,
    shuffle=True,
    seed=1337,
    image_size=image_size,
    batch_size=batch_size
)
# Out:
# Found 15515 files belonging to 12 classes.
# Using 12412 files for training.
# Using 3103 files for validation.
# 2024-03-22 20:40:56.326378: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-22 20:40:56.348973: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-22 20:40:56.349027: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-22 20:40:56.349829: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-22 20:40:56.350565: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-22 20:40:56.350607: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-22 20:40:56.350624: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-22 20:40:57.021917: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-22 20:40:57.022041: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-22 20:40:57.022051: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1700] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-03-22 20:40:57.022077: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-22 20:40:57.022187: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4989 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Ti, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
class_names = train_ds.class_names
class_names
# Out:
# ['battery',
#  'biological',
#  'brown-glass',
#  'cardboard',
#  'clothes',
#  'green-glass',
#  'metal',
#  'paper',
#  'plastic',
#  'shoes',
#  'trash',
#  'white-glass']

# %%
for image_batch, labels_batch in train_ds:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (32, 256, 256, 3)
# (32,)

# %%
plt.figure(figsize=(10,10))
for images, labels in train_ds.take(1):
    indexes = []
    for _ in range(9):
        indexes.append(random.randint(0, batch_size-1))
    for i, ind in enumerate(indexes):
        ax = plt.subplot(3,3,i+1)
        plt.imshow(np.array(images[ind]).astype("uint8"))
        plt.title(class_names[int(labels[ind])])
        plt.axis("off")

# %%
tf.data.experimental.cardinality(train_ds).numpy()
# Out:
# 388

# %% [markdown]
# 388 batches of data, wow

# %% [markdown]
# ## Data augmentation setup

# %%
for folder in os.listdir(f"./{ds_folder}"):
    # file_count = len([name for name in os.listdir(f'./garbage_classification/{folder}') if os.path.isfile(name)])
    file_count = len(os.listdir(f'./garbage_classification/{folder}'))
    print(f'{folder} class count: {file_count}')
# Out:
# battery class count: 945
# biological class count: 985
# brown-glass class count: 607
# cardboard class count: 891
# clothes class count: 5325
# green-glass class count: 629
# metal class count: 769
# paper class count: 1050
# plastic class count: 865
# shoes class count: 1977
# trash class count: 697
# white-glass class count: 775

# %% [markdown]
# It would seem the 'clothes' class seems to heavily (over 5x) overrepresent the dataset, which, on the other hand might make sense, as the class includes multiple articles of clothes, which can vary significantly (think shoes vs shirts vs pants).
#
# Other than that, the data could always use some augmentation, as in simulating taking the photos of the images from different angles, in different circumstances.

# %%
data_augmentation_layers = [
    layers.RandomFlip("horizontal"),
    layers.RandomFlip("vertical"),
    layers.RandomBrightness(factor=0.1),
    layers.RandomRotation(factor=0.1),
    layers.RandomZoom(height_factor=0.1)
]

def data_augmentation(images):
    for layer in data_augmentation_layers:
        images = layer(images)
    return images

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(np.array(augmented_images[0]).astype("uint8"))
        plt.axis("off")
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:5 out of the last 5 calls to <function pfor.<locals>.f at 0x7fcf602c81f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:6 out of the last 6 calls to <function pfor.<locals>.f at 0x7fcf602c8310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %%
# Apply `data_augmentation` to the training images.
train_ds_aug = train_ds.map(
    lambda img, label: (data_augmentation(img), label),
    num_parallel_calls=tf.data.AUTOTUNE,
)
# Prefetching samples in GPU memory helps maximize GPU utilization.
train_ds_aug = train_ds_aug.prefetch(tf.data.AUTOTUNE)
val_ds = val_ds.prefetch(tf.data.AUTOTUNE)
# Out:
# WARNING:tensorflow:From /home/user/.local/lib/python3.10/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %% [markdown]
# # Modelling

# %% [markdown]
# ### Simple conv model unaugmented data

# %%
num_classes = len(class_names)

# %%
model_small = tf.keras.Sequential([
    layers.Rescaling(1./255),
    layers.Conv2D(filters=64,  kernel_size = 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(filters=64,  kernel_size = 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(filters=64,  kernel_size = 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(num_classes),
    layers.Softmax()
])

# %%
model_small.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
early_stop = tf.keras.callbacks.EarlyStopping(
    monitor = "val_accuracy",
    min_delta = 0.01,
    patience = 5,
    verbose = 0,
    restore_best_weights=True
)

# %%
callbacks = [
    # keras.callbacks.ModelCheckpoint("three_batchnorm_at_{epoch}.keras"),
    early_stop
]

# %%
epochs = 25

# %%
history = model_small.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs,
    # callbacks = callbacks
)
# Out:
# Epoch 1/25
# 2024-03-22 20:47:06.269766: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8100
# 2024-03-22 20:47:15.446327: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-03-22 20:47:21.772752: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2024-03-22 20:47:21.820234: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x55eb8a1402b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-03-22 20:47:21.820282: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Ti, Compute Capability 8.6
# 2024-03-22 20:47:21.846126: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-03-22 20:47:22.333052: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-03-22 20:47:25.390834: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 388/388 [==============================] - 60s 66ms/step - loss: 1.4346 - accuracy: 0.5342 - val_loss: 1.0909 - val_accuracy: 0.6465
# Epoch 2/25
# 388/388 [==============================] - 21s 55ms/step - loss: 0.9329 - accuracy: 0.6926 - val_loss: 1.0618 - val_accuracy: 0.6729
# Epoch 3/25
# 388/388 [==============================] - 21s 54ms/step - loss: 0.7214 - accuracy: 0.7593 - val_loss: 0.9408 - val_accuracy: 0.7154
# Epoch 4/25
# 388/388 [==============================] - 23s 58ms/step - loss: 0.5217 - accuracy: 0.8270 - val_loss: 1.0775 - val_accuracy: 0.7196
# Epoch 5/25
# 388/388 [==============================] - 21s 55ms/step - loss: 0.3628 - accuracy: 0.8810 - val_loss: 1.2932 - val_accuracy: 0.7148
# Epoch 6/25
# 388/388 [==============================] - 21s 54ms/step - loss: 0.2475 - accuracy: 0.9198 - val_loss: 1.4065 - val_accuracy: 0.6851
# Epoch 7/25
# 388/388 [==============================] - 21s 54ms/step - loss: 0.1895 - accuracy: 0.9390 - val_loss: 1.5566 - val_accuracy: 0.6987
# Epoch 8/25
# 388/388 [==============================] - 21s 54ms/step - loss: 0.1294 - accuracy: 0.9586 - val_loss: 1.9763 - val_accuracy: 0.6922
# Epoch 9/25
# 388/388 [==============================] - 21s 54ms/step - loss: 0.1365 - accuracy: 0.9541 - val_loss: 1.5597 - val_accuracy: 0.7077
# Epoch 10/25
# 388/388 [==============================] - 21s 54ms/step - loss: 0.0921 - accuracy: 0.9709 - val_loss: 2.0844 - val_accuracy: 0.7080
# Epoch 11/25
# 388/388 [==============================] - 21s 54ms/step - loss: 0.1048 - accuracy: 0.9691 - val_loss: 1.9434 - val_accuracy: 0.6893
# Epoch 12/25
# 388/388 [==============================] - 21s 54ms/step - loss: 0.0820 - accuracy: 0.9749 - val_loss: 2.3993 - val_accuracy: 0.7035
# Epoch 13/25
# 388/388 [==============================] - 21s 54ms/step - loss: 0.0712 - accuracy: 0.9771 - val_loss: 2.2182 - val_accuracy: 0.7148
# Epoch 14/25
# 388/388 [==============================] - 21s 54ms/step - loss: 0.0618 - accuracy: 0.9804 - val_loss: 2.5145 - val_accuracy: 0.6996
# Epoch 15/25
# 388/388 [==============================] - 21s 54ms/step - loss: 0.0899 - accuracy: 0.9728 - val_loss: 2.4853 - val_accuracy: 0.6906
# Epoch 16/25
# 388/388 [==============================] - 21s 54ms/step - loss: 0.0547 - accuracy: 0.9849 - val_loss: 2.3648 - val_accuracy: 0.7096
# Epoch 17/25
# 388/388 [==============================] - 21s 54ms/step - loss: 0.0388 - accuracy: 0.9873 - val_loss: 2.7668 - val_accuracy: 0.7077
# Epoch 18/25
# 388/388 [==============================] - 21s 54ms/step - loss: 0.0701 - accuracy: 0.9804 - val_loss: 2.5412 - val_accuracy: 0.6922
# Epoch 19/25
# 388/388 [==============================] - 21s 54ms/step - loss: 0.0380 - accuracy: 0.9890 - val_loss: 2.6201 - val_accuracy: 0.7093
# Epoch 20/25
# 388/388 [==============================] - 21s 54ms/step - loss: 0.0478 - accuracy: 0.9860 - val_loss: 2.9776 - val_accuracy: 0.6980
# Epoch 21/25
# 388/388 [==============================] - 21s 54ms/step - loss: 0.0447 - accuracy: 0.9868 - val_loss: 2.9013 - val_accuracy: 0.7080
# Epoch 22/25
# 388/388 [==============================] - 21s 54ms/step - loss: 0.0323 - accuracy: 0.9915 - val_loss: 3.1007 - val_accuracy: 0.6855
# Epoch 23/25
# 388/388 [==============================] - 20s 50ms/step - loss: 0.0474 - accuracy: 0.9880 - val_loss: 3.2031 - val_accuracy: 0.6764
# Epoch 24/25
# 388/388 [==============================] - 19s 50ms/step - loss: 0.0580 - accuracy: 0.9863 - val_loss: 2.9474 - val_accuracy: 0.6993
# Epoch 25/25
# 388/388 [==============================] - 20s 52ms/step - loss: 0.0236 - accuracy: 0.9918 - val_loss: 3.0975 - val_accuracy: 0.7132

# %%
history_df = pd.DataFrame(history.history)
history_df[['loss', 'val_loss']].plot()
# Out:
# <Axes: >

# %%
history_df[['accuracy', 'val_accuracy']].plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Evaluation metrics

# %%
# sklearn classification metrics
from sklearn.metrics  import (f1_score ,accuracy_score, confusion_matrix,
                            classification_report, ConfusionMatrixDisplay, 
                            roc_curve, precision_recall_curve,
                            auc, make_scorer, recall_score, accuracy_score, precision_score
                            )

# %%
test_preds = model_small.predict(val_ds)
test_labels = np.concatenate([y for x,y in val_ds], axis=0)
test_preds_argmax = test_preds.argmax(axis=1)

nn_clf_report = classification_report(test_labels, test_preds_argmax, target_names = class_names)
print(nn_clf_report)

nn_cm = confusion_matrix(test_labels, test_preds_argmax)
nn_cm_disp = ConfusionMatrixDisplay(nn_cm, display_labels = class_names)
nn_cm_disp.plot(xticks_rotation=-90)
# Out:
# 97/97 [==============================] - 2s 16ms/step
#               precision    recall  f1-score   support
#
#      battery       0.70      0.50      0.59       212
#   biological       0.76      0.69      0.72       188
#  brown-glass       0.70      0.54      0.61       118
#    cardboard       0.60      0.69      0.64       203
#      clothes       0.85      0.95      0.90      1059
#  green-glass       0.77      0.88      0.82       116
#        metal       0.38      0.31      0.34       158
#        paper       0.64      0.70      0.67       202
#      plastic       0.56      0.46      0.51       185
#        shoes       0.59      0.60      0.60       379
#        trash       0.71      0.58      0.64       136
#  white-glass       0.58      0.52      0.54       147
#
#     accuracy                           0.71      3103
#    macro avg       0.65      0.62      0.63      3103
# weighted avg       0.70      0.71      0.70      3103

# %% [markdown]
# The results? okay, but quite far from perfect

# %% [markdown]
# ## Transfer learning
# starting with EfficientNetB0, as it is easily accessible in keras

# %%
from keras.applications import EfficientNetB0

# %%
image_size = (224, 224)
batch_size = 32

# %%
train_ds, val_ds = keras.utils.image_dataset_from_directory(
    directory = f"{ds_folder}",
    labels = "inferred",
    color_mode = "rgb",
    subset="both",
    validation_split=0.2,
    shuffle=True,
    seed=1337,
    image_size=image_size,
    batch_size=batch_size
)
# Out:
# Found 15515 files belonging to 12 classes.
# Using 12412 files for training.
# Using 3103 files for validation.
# 2024-03-22 21:25:07.184652: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-22 21:25:07.253637: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-22 21:25:07.253684: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-22 21:25:07.256779: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-22 21:25:07.258518: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-22 21:25:07.258556: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-22 21:25:07.258571: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-22 21:25:08.630233: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-22 21:25:08.630902: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-22 21:25:08.630918: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1700] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-03-22 21:25:08.630946: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-03-22 21:25:08.631362: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5434 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Ti, pci bus id: 0000:01:00.0, compute capability: 8.6

# %% [markdown]
# ### preprocessing for EfficientNet (OHEncoding the labels?)

# %%
# One-hot / categorical encoding
def input_preprocess_train(image, label):
    # image = img_augmentation(image)
    label = tf.one_hot(int(label), num_classes)
    return image, label


def input_preprocess_test(image, label):
    label = tf.one_hot(int(label), num_classes)
    return image, label


train_ds = train_ds.map(input_preprocess_train, num_parallel_calls=tf.data.AUTOTUNE)
# train_ds = train_ds.batch(batch_size=batch_size, drop_remainder=True)
# train_ds = train_ds.prefetch(tf.data.AUTOTUNE)

val_ds = val_ds.map(input_preprocess_test, num_parallel_calls=tf.data.AUTOTUNE)
# val_ds = val_ds.batch(batch_size=batch_size, drop_remainder=True)

# %% [markdown]
# ### from pre-trained weights

# %%
for image_batch, labels_batch in train_ds:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (32, 224, 224, 3)
# (32, 12)

# %%
IMG_SIZE = 224
num_classes = 12
NUM_CLASSES = 12

# %%
def build_model(num_classes):
    inputs = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    model = EfficientNetB0(include_top=False, input_tensor=inputs, weights="imagenet")

    # Freeze the pretrained weights
    model.trainable = False

    # Rebuild top
    x = layers.GlobalAveragePooling2D(name="avg_pool")(model.output)
    x = layers.BatchNormalization()(x)

    top_dropout_rate = 0.2
    x = layers.Dropout(top_dropout_rate, name="top_dropout")(x)
    outputs = layers.Dense(num_classes, activation="softmax", name="pred")(x)

    # Compile
    model = keras.Model(inputs, outputs, name="EfficientNet")
    optimizer = keras.optimizers.Adam(learning_rate=1e-2)
    model.compile(
        optimizer=optimizer, loss="categorical_crossentropy", metrics=["accuracy"]
    )
    return model

# %%
model = build_model(num_classes=NUM_CLASSES)

epochs = 25  # @param {type: "slider", min:8, max:80}
hist = model.fit(train_ds, epochs=epochs, validation_data=val_ds)
plot_hist(hist)
# Out:
# Epoch 1/25
# 2024-03-22 21:30:09.381349: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inEfficientNet/block2b_drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2024-03-22 21:30:11.116840: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8100
# 2024-03-22 21:30:12.637675: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-03-22 21:30:13.860752: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2024-03-22 21:30:14.022886: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x55d6ea7075c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-03-22 21:30:14.022918: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Ti, Compute Capability 8.6
# 2024-03-22 21:30:14.056321: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
#   1/388 [..............................] - ETA: 52:03 - loss: 3.8804 - accuracy: 0.0625
# 2024-03-22 21:30:14.361977: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-03-22 21:30:14.378665: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 388/388 [==============================] - 33s 65ms/step - loss: 0.6386 - accuracy: 0.8970 - val_loss: 0.4261 - val_accuracy: 0.9236
# Epoch 2/25
# 388/388 [==============================] - 24s 61ms/step - loss: 0.4511 - accuracy: 0.9322 - val_loss: 0.3404 - val_accuracy: 0.9523
# Epoch 3/25
# 388/388 [==============================] - 24s 61ms/step - loss: 0.3738 - accuracy: 0.9426 - val_loss: 0.3714 - val_accuracy: 0.9491
# Epoch 4/25
# 388/388 [==============================] - 24s 60ms/step - loss: 0.3865 - accuracy: 0.9418 - val_loss: 0.4437 - val_accuracy: 0.9426
# Epoch 5/25
# 388/388 [==============================] - 23s 60ms/step - loss: 0.3671 - accuracy: 0.9456 - val_loss: 0.4251 - val_accuracy: 0.9407
# Epoch 6/25
# 388/388 [==============================] - 23s 60ms/step - loss: 0.3342 - accuracy: 0.9475 - val_loss: 0.4374 - val_accuracy: 0.9433
# Epoch 7/25
# 388/388 [==============================] - 23s 59ms/step - loss: 0.3481 - accuracy: 0.9492 - val_loss: 0.3922 - val_accuracy: 0.9488
# Epoch 8/25
# 388/388 [==============================] - 23s 59ms/step - loss: 0.2996 - accuracy: 0.9540 - val_loss: 0.4499 - val_accuracy: 0.9423
# Epoch 9/25
# 388/388 [==============================] - 23s 60ms/step - loss: 0.3536 - accuracy: 0.9494 - val_loss: 0.4275 - val_accuracy: 0.9523
# Epoch 10/25
# 388/388 [==============================] - 23s 60ms/step - loss: 0.3464 - accuracy: 0.9514 - val_loss: 0.5135 - val_accuracy: 0.9365
# Epoch 11/25
# 388/388 [==============================] - 23s 59ms/step - loss: 0.3339 - accuracy: 0.9528 - val_loss: 0.5295 - val_accuracy: 0.9381
# Epoch 12/25
# 388/388 [==============================] - 23s 60ms/step - loss: 0.3502 - accuracy: 0.9542 - val_loss: 0.4989 - val_accuracy: 0.9484
# Epoch 13/25
# 388/388 [==============================] - 23s 60ms/step - loss: 0.3397 - accuracy: 0.9534 - val_loss: 0.4352 - val_accuracy: 0.9555
# Epoch 14/25
# 388/388 [==============================] - 23s 59ms/step - loss: 0.3509 - accuracy: 0.9542 - val_loss: 0.4583 - val_accuracy: 0.9526
# Epoch 15/25
# 388/388 [==============================] - 23s 60ms/step - loss: 0.3386 - accuracy: 0.9554 - val_loss: 0.4385 - val_accuracy: 0.9526
# Epoch 16/25
# 388/388 [==============================] - 23s 60ms/step - loss: 0.3311 - accuracy: 0.9574 - val_loss: 0.5384 - val_accuracy: 0.9500
# Epoch 17/25
# 388/388 [==============================] - 23s 60ms/step - loss: 0.3551 - accuracy: 0.9568 - val_loss: 0.4879 - val_accuracy: 0.9523
# Epoch 18/25
# 388/388 [==============================] - 23s 60ms/step - loss: 0.3293 - accuracy: 0.9578 - val_loss: 0.5221 - val_accuracy: 0.9520
# Epoch 19/25
# 388/388 [==============================] - 23s 60ms/step - loss: 0.3741 - accuracy: 0.9585 - val_loss: 0.5792 - val_accuracy: 0.9484
# Epoch 20/25
# 388/388 [==============================] - 23s 60ms/step - loss: 0.4021 - accuracy: 0.9538 - val_loss: 0.5350 - val_accuracy: 0.9552
# Epoch 21/25
# 388/388 [==============================] - 23s 59ms/step - loss: 0.3666 - accuracy: 0.9574 - val_loss: 0.5527 - val_accuracy: 0.9517
# Epoch 22/25
# 388/388 [==============================] - 23s 60ms/step - loss: 0.3882 - accuracy: 0.9567 - val_loss: 0.5244 - val_accuracy: 0.9571
# Epoch 23/25
# 388/388 [==============================] - 23s 60ms/step - loss: 0.3694 - accuracy: 0.9582 - val_loss: 0.4983 - val_accuracy: 0.9558
# Epoch 24/25
# 388/388 [==============================] - 23s 60ms/step - loss: 0.3934 - accuracy: 0.9557 - val_loss: 0.5781 - val_accuracy: 0.9539
# Epoch 25/25
# 388/388 [==============================] - 23s 60ms/step - loss: 0.3792 - accuracy: 0.9592 - val_loss: 0.6247 - val_accuracy: 0.9500
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 5
#       3 epochs = 25  # @param {type: "slider", min:8, max:80}
#       4 hist = model.fit(train_ds, epochs=epochs, validation_data=val_ds)
# ----> 5 plot_hist(hist)
#
# NameError: name 'plot_hist' is not defined

# %%
# sklearn classification metrics
from sklearn.metrics  import (f1_score ,accuracy_score, confusion_matrix,
                            classification_report, ConfusionMatrixDisplay, 
                            roc_curve, precision_recall_curve,
                            auc, make_scorer, recall_score, accuracy_score, precision_score
                            )

# %%
history_df = pd.DataFrame(hist.history)
history_df[['loss', 'val_loss']].plot()
# Out:
# <Axes: >

# %%
history_df[['accuracy', 'val_accuracy']].plot()
# Out:
# <Axes: >

# %%
class_names = ['battery',
 'biological',
 'brown-glass',
 'cardboard',
 'clothes',
 'green-glass',
 'metal',
 'paper',
 'plastic',
 'shoes',
 'trash',
 'white-glass']

# %%
test_preds = model.predict(val_ds)
test_labels = np.concatenate([y for x,y in val_ds], axis=0)
test_preds_argmax = test_preds.argmax(axis=1)

nn_clf_report = classification_report(test_labels, test_preds_argmax, target_names = class_names)
print(nn_clf_report)

nn_cm = confusion_matrix(test_labels, test_preds_argmax)
nn_cm_disp = ConfusionMatrixDisplay(nn_cm, display_labels = class_names)
nn_cm_disp.plot(xticks_rotation=-90)
# Out:
# 97/97 [==============================] - 5s 47ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 5
#       2 test_labels = np.concatenate([y for x,y in val_ds], axis=0)
#       3 test_preds_argmax = test_preds.argmax(axis=1)
# ----> 5 nn_clf_report = classification_report(test_labels, test_preds_argmax, target_names = class_names)
#       6 print(nn_clf_report)
#       8 nn_cm = confusion_matrix(test_labels, test_preds_argmax)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:2604, in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    2469 @validate_params(
#    2470     {
#    2471         "y_true": ["array-like", "sparse matrix"],
#    (...)
#    2495     zero_division="warn",
#    2496 ):
#    2497     """Build a text report showing the main classification metrics.
#    2498
#    2499     Read more in the :ref:`User Guide <classification_report>`.
#    (...)
#    2601     <BLANKLINE>
#    2602     """
# -> 2604     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    2606     if labels is None:
#    2607         labels = unique_labels(y_true, y_pred)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:94, in _check_targets(y_true, y_pred)
#      91     y_type = {"multiclass"}
#      93 if len(y_type) > 1:
# ---> 94     raise ValueError(
#      95         "Classification metrics can't handle a mix of {0} and {1} targets".format(
#      96             type_true, type_pred
#      97         )
#      98     )
#     100 # We can't have more than one value on y_type => The set is no more needed
#     101 y_type = y_type.pop()
#
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets

# %% [markdown]
# Nice, 95% validation accuracy, almost perfect

# %% [markdown]
# ## TODO: https://www.tensorflow.org/tfx/model_analysis/metrics

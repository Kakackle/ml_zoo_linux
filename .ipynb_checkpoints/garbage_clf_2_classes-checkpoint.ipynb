# %% [markdown]
# # Garbage classification project
# With tensorflow on CUDA
#
# And dataset from **[kaggle](https://www.kaggle.com/datasets/mostafaabla/garbage-classification?select=garbage_classification)**, consisting of 15,150 images from 12 different classes of household garbage; paper, cardboard, biological, metal, plastic, green-glass, brown-glass, white-glass, clothes, shoes, batteries, and trash (dirty garbage, face masks etc, non-recyclable)

# %% [markdown]
# ### Limiting the problem to 3 classes (out of 12) as benchmark
# To start off, let's work with only **3** of these classes, as a benchmark of the problem difficulty, with faster execution time due to less classes. The 3 chosen classess (partially arbitratily, but theoritically sufficiently different) are: paper, plastic, batteries

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow import keras

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import random
import os

# %% [markdown]
# ## Downloading the whole dataset

# %%
# !wget -L "https://drive.google.com/uc?export=download&id=1qoFPTgm4bqfS2kx0luMkMgUs7fKrk376"

# %%
# !gdown "https://drive.google.com/uc?export=download&id=1qoFPTgm4bqfS2kx0luMkMgUs7fKrk376"

# %% [markdown]
# #### unzip

# %%
# %%time
# !unrar x -idp garbage_classification.rar

# %%
# !ls garbage_classification
# Out:
# /bin/bash: /home/user/miniconda3/envs/tf/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# battery     brown-glass  clothes      metal  plastic  trash
# biological  cardboard	 green-glass  paper  shoes    white-glass

# %% [markdown]
# ## Random seed for reproducibility

# %%
tf.random.set_seed(1337)

# %% [markdown]
# ## Create dataset from files
# using keras utils, to create a training and validation split and batch the images

# %% [markdown]
# #### dataset folder name variable 'ds_folder'

# %%
ds_folder = "garbage_classification_three"

# %%
image_size = (256, 256)
batch_size = 32

# %%
train_ds, val_ds = keras.utils.image_dataset_from_directory(
    directory = f"{ds_folder}",
    labels = "inferred",
    color_mode = "rgb",
    subset="both",
    validation_split=0.2,
    shuffle=True,
    seed=1337,
    image_size=image_size,
    batch_size=batch_size
)
# Out:
# Found 2860 files belonging to 3 classes.
# Using 2288 files for training.
# Using 572 files for validation.

# %%
class_names = train_ds.class_names
class_names
# Out:
# ['battery', 'paper', 'plastic']

# %% [markdown]
# ### Explore some of the images

# %%
for image_batch, labels_batch in train_ds:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (32, 256, 256, 3)
# (32,)

# %%
plt.figure(figsize=(10,10))
for images, labels in train_ds.take(1):
    indexes = []
    for _ in range(9):
        indexes.append(random.randint(0, batch_size-1))
    for i, ind in enumerate(indexes):
        ax = plt.subplot(3,3,i+1)
        plt.imshow(np.array(images[ind]).astype("uint8"))
        plt.title(class_names[int(labels[ind])])
        plt.axis("off")

# %%
tf.data.experimental.cardinality(train_ds).numpy()
# Out:
# 388

# %% [markdown]
# ## Data augmentation?
# Before engaging in data augmentation, let's count the numbers of class instances in the dataset - are there any imbalances? Is the dataset large enough?

# %%
for folder in os.listdir(f"./{ds_folder}"):
    # file_count = len([name for name in os.listdir(f'./garbage_classification/{folder}') if os.path.isfile(name)])
    file_count = len(os.listdir(f'./garbage_classification/{folder}'))
    print(f'{folder} class count: {file_count}')
# Out:
# battery class count: 945
# paper class count: 1050
# plastic class count: 865

# %% [markdown]
# It would seem the 'clothes' class seems to heavily (over 5x) overrepresent the dataset, which, on the other hand might make sense, as the class includes multiple articles of clothes, which can vary significantly (think shoes vs shirts vs pants).
#
# Other than that, the data could always use some augmentation, as in simulating taking the photos of the images from different angles, in different circumstances.

# %%
data_augmentation_layers = [
    layers.RandomFlip("horizontal"),
    layers.RandomFlip("vertical"),
    layers.RandomBrightness(factor=0.1),
    layers.RandomRotation(factor=0.1),
    layers.RandomZoom(height_factor=0.1)
]

def data_augmentation(images):
    for layer in data_augmentation_layers:
        images = layer(images)
    return images

# %%
# plt.figure(figsize=(10,10))
# for images, labels in train_ds.take(1):
#     indexes = []
#     for _ in range(9):
#         indexes.append(random.randint(0, batch_size))
#     augmented_images = data_augmentation(images)
#     for i, ind in enumerate(indexes):
#         ax = plt.subplot(3,3,i+1)
#         plt.imshow(np.array(augmented_images[0]).astype("uint8"))
#         plt.title(class_names[int(labels[0])])
#         plt.axis("off")

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(np.array(augmented_images[0]).astype("uint8"))
        plt.axis("off")
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %% [markdown]
# ### applying augmentation to train data
# Note: this doesn't actually apply these transformations now - it creates a mapping with batching and prefetching, that will be called asynchronously during retrieving the batches during the fitting process

# %%
# Apply `data_augmentation` to the training images.
train_ds = train_ds.map(
    lambda img, label: (data_augmentation(img), label),
    num_parallel_calls=tf.data.AUTOTUNE,
)
# Prefetching samples in GPU memory helps maximize GPU utilization.
train_ds = train_ds.prefetch(tf.data.AUTOTUNE)
val_ds = val_ds.prefetch(tf.data.AUTOTUNE)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %% [markdown]
# ## Modelling

# %% [markdown]
# ### Simple conv model

# %%
num_classes = len(class_names)

# %%
model_small = tf.keras.Sequential([
    layers.Rescaling(1./255),
    layers.Conv2D(filters=64,  kernel_size = 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(filters=64,  kernel_size = 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(filters=64,  kernel_size = 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(num_classes),
    layers.Softmax()
])

# %% [markdown]
# ### Important - when dealing with image (or other heavy data format) - modelcheckpoints can prove very beneficiary
# Along with other callbacks like earlystopping

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint("model_small_three_at_{epoch}.keras"),
]

# %%
model_small.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
epochs = 10

# %% [markdown]
# ### GPU memory fix?

# %%
# config = tf.compat.v1.ConfigProto()
# config.gpu_options.allow_growth = True
# sess = tf.compat.v1.Session(config=config)

# %%
history = model_small.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs,
    callbacks = callbacks
)
# Out:
# Epoch 1/10
# 72/72 [==============================] - 9s 94ms/step - loss: 0.9846 - accuracy: 0.5664 - val_loss: 0.8400 - val_accuracy: 0.6014
# Epoch 2/10
# 72/72 [==============================] - 6s 81ms/step - loss: 0.6303 - accuracy: 0.7395 - val_loss: 0.8191 - val_accuracy: 0.6696
# Epoch 3/10
# 72/72 [==============================] - 6s 77ms/step - loss: 0.5612 - accuracy: 0.7653 - val_loss: 0.5718 - val_accuracy: 0.7517
# Epoch 4/10
# 72/72 [==============================] - 6s 78ms/step - loss: 0.4933 - accuracy: 0.7902 - val_loss: 0.7390 - val_accuracy: 0.6818
# Epoch 5/10
# 72/72 [==============================] - 7s 83ms/step - loss: 0.4680 - accuracy: 0.8020 - val_loss: 0.5859 - val_accuracy: 0.7430
# Epoch 6/10
# 72/72 [==============================] - 6s 77ms/step - loss: 0.3852 - accuracy: 0.8422 - val_loss: 0.5730 - val_accuracy: 0.7832
# Epoch 7/10
# 72/72 [==============================] - 7s 82ms/step - loss: 0.3870 - accuracy: 0.8492 - val_loss: 0.7168 - val_accuracy: 0.7010
# Epoch 8/10
# 72/72 [==============================] - 6s 83ms/step - loss: 0.3648 - accuracy: 0.8492 - val_loss: 0.8828 - val_accuracy: 0.6171
# Epoch 9/10
# 72/72 [==============================] - 6s 75ms/step - loss: 0.3543 - accuracy: 0.8628 - val_loss: 0.7056 - val_accuracy: 0.7028
# Epoch 10/10
# 72/72 [==============================] - 7s 90ms/step - loss: 0.3178 - accuracy: 0.8676 - val_loss: 0.7171 - val_accuracy: 0.6993

# %%
history_df = pd.DataFrame(history.history)
history_df[['loss', 'val_loss']].plot()
# Out:
# <Axes: >

# %%
history_df[['accuracy', 'val_accuracy']].plot()
# Out:
# <Axes: >

# %% [markdown]
# The end accuracy of the model is around 85%, but, looking at the learning curves, it seems it might be overfitting quite a bit, even though it's capacity is not that large (for a convolutional model)

# %%
model_small.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_2 (Rescaling)     (None, 256, 256, 3)       0
#
#  conv2d_6 (Conv2D)           (None, 254, 254, 64)      1792
#
#  max_pooling2d_6 (MaxPooling  (None, 127, 127, 64)     0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 125, 125, 64)      36928
#
#  max_pooling2d_7 (MaxPooling  (None, 62, 62, 64)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 60, 60, 64)        36928
#
#  max_pooling2d_8 (MaxPooling  (None, 30, 30, 64)       0
#  2D)
#
#  flatten_2 (Flatten)         (None, 57600)             0
#
#  dense_4 (Dense)             (None, 128)               7372928
#
#  dense_5 (Dense)             (None, 3)                 387
#
#  softmax_2 (Softmax)         (None, 3)                 0
#
# =================================================================
# Total params: 7,448,963
# Trainable params: 7,448,963
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Testing the model's predictive capabilities

# %%
sample_images = []
sample_labels = []
for _ in range(9):
    random_label = random.choice(class_names)
    sample_labels.append(random_label)
    random_img_path = random.choice(os.listdir(f"./{ds_folder}/{random_label}"))
    img = keras.utils.load_img(f"./{ds_folder}/{random_label}/{random_img_path}",
                              target_size=image_size)
    img_array = keras.utils.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)
    sample_images.append(img_array)

# %%
# sample_images = tf.expand_dims(sample_images, 0)

# %%
len(sample_images)
# Out:
# 9

# %%
sample_preds = []
sample_argmax = []
for img in sample_images:
    predictions = model_small.predict(img)
    # preds = np.argmax(predictions, 1)[0]
    sample_preds.append(predictions)
    sample_argmax.append(np.argmax(predictions,1)[0])
print(sample_preds)
print(sample_argmax)
# Out:
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# [array([[0.3946592 , 0.08839273, 0.5169481 ]], dtype=float32), array([[1.3754994e-01, 8.6195314e-01, 4.9688708e-04]], dtype=float32), array([[7.500966e-04, 9.986601e-01, 5.898000e-04]], dtype=float32), array([[0.9926103 , 0.00287174, 0.00451806]], dtype=float32), array([[6.2701225e-02, 9.3729872e-01, 9.8469044e-10]], dtype=float32), array([[0.9673922 , 0.01778463, 0.01482314]], dtype=float32), array([[0.8438931 , 0.00461491, 0.15149193]], dtype=float32), array([[0.00127463, 0.10360284, 0.8951226 ]], dtype=float32), array([[0.01844048, 0.07681425, 0.9047453 ]], dtype=float32)]
# [2, 1, 1, 0, 1, 0, 0, 2, 2]

# %%
def plot_image(i, predictions_array, true_label, img):
  true_label, img = true_label[i], img[i]
  img = tf.squeeze(img, 0)
  img = img/255
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary, vmin=0, vmax=255)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(predictions_array),
                                class_names[true_label]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  true_label = true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(3), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %%
sample_preds[3][0]
# Out:
# array([0.9926103 , 0.00287174, 0.00451806], dtype=float32)

# %%
i = 3
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, sample_preds[i][0], sample_argmax, sample_images)
plt.subplot(1,2,2)
plot_value_array(i, sample_preds[i][0],  sample_argmax)
plt.show()

# %%
# Plot the first X test images, their predicted labels, and the true labels.
# Color correct predictions in blue and incorrect predictions in red.
num_rows = 3
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, sample_preds[i][0], sample_argmax, sample_images)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, sample_preds[i][0], sample_argmax)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Evaluation metrics

# %%
# sklearn classification metrics
from sklearn.metrics  import (f1_score ,accuracy_score, confusion_matrix,
                            classification_report, ConfusionMatrixDisplay, 
                            roc_curve, precision_recall_curve,
                            auc, make_scorer, recall_score, accuracy_score, precision_score
                            )

# %%
test_preds = model_small.predict(val_ds)
# Out:
# 18/18 [==============================] - 1s 39ms/step

# %%
test_preds.shape
# Out:
# (572, 3)

# %%
test_labels = np.concatenate([y for x,y in val_ds], axis=0)

# %%
test_labels.shape
# Out:
# (572,)

# %%
test_preds_argmax = test_preds.argmax(axis=1)
test_preds_argmax[:10]
# Out:
# array([1, 1, 0, 1, 2, 1, 2, 0, 2, 0])

# %%
nn_clf_report = classification_report(test_labels, test_preds_argmax, target_names = class_names)
print(nn_clf_report)
# Out:
#               precision    recall  f1-score   support
#
#      battery       0.73      0.82      0.77       180
#        paper       0.88      0.52      0.65       216
#      plastic       0.58      0.80      0.67       176
#
#     accuracy                           0.70       572
#    macro avg       0.73      0.71      0.70       572
# weighted avg       0.74      0.70      0.70       572

# %%
nn_cm = confusion_matrix(test_labels, test_preds_argmax)
nn_cm_disp = ConfusionMatrixDisplay(nn_cm, display_labels = class_names)
nn_cm_disp.plot(xticks_rotation=-90)

# %% [markdown]
# It seems the model confuses paper for plastic quite often, resulting in a low recall score for images of class 'paper', noticeably lowering the overall accuracy score.
#
# Looking at the training curves, perhaps we can improve the model's learning by reducing the overfitting. Let's do that.
#
# Also, we can add a callback that will stop the training early and restore the best performing weights, whilst increasing the maximum number of allowed epochs
#
# For reducing overfit, we cannot introduce dropout layers as with fully-connected networks, but a batchnorm can still be utilized.

# %%
model_small_batchnorm = tf.keras.Sequential([
    layers.Rescaling(1./255),
    layers.Conv2D(filters=64,  kernel_size = 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.BatchNormalization(),
    layers.Conv2D(filters=64,  kernel_size = 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.BatchNormalization(),
    layers.Conv2D(filters=64,  kernel_size = 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.BatchNormalization(),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(num_classes),
    layers.Softmax()
])

# %%
early_stop = tf.keras.callbacks.EarlyStopping(
    monitor = "val_accuracy",
    min_delta = 0.01,
    patience = 5,
    verbose = 0,
    restore_best_weights=True
)

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint("three_batchnorm_at_{epoch}.keras"),
    early_stop
]

# %%
model_small_batchnorm.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
epochs = 25

# %%
history = model_small_batchnorm.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs,
    callbacks = callbacks
)
# Out:
# Epoch 1/25
# 72/72 [==============================] - 8s 80ms/step - loss: 4.6592 - accuracy: 0.7080 - val_loss: 14.9368 - val_accuracy: 0.3969
# Epoch 2/25
# 72/72 [==============================] - 7s 92ms/step - loss: 2.1064 - accuracy: 0.7714 - val_loss: 14.7026 - val_accuracy: 0.3811
# Epoch 3/25
# 72/72 [==============================] - 7s 84ms/step - loss: 1.5564 - accuracy: 0.7946 - val_loss: 13.2935 - val_accuracy: 0.3811
# Epoch 4/25
# 72/72 [==============================] - 6s 80ms/step - loss: 1.2102 - accuracy: 0.7749 - val_loss: 4.0602 - val_accuracy: 0.3566
# Epoch 5/25
# 72/72 [==============================] - 7s 87ms/step - loss: 0.9264 - accuracy: 0.8103 - val_loss: 2.5325 - val_accuracy: 0.5297
# Epoch 6/25
# 72/72 [==============================] - 8s 103ms/step - loss: 0.7229 - accuracy: 0.8374 - val_loss: 4.0645 - val_accuracy: 0.3566
# Epoch 7/25
# 72/72 [==============================] - 7s 89ms/step - loss: 0.5437 - accuracy: 0.8322 - val_loss: 13.7464 - val_accuracy: 0.3986
# Epoch 8/25
# 72/72 [==============================] - 7s 86ms/step - loss: 0.5244 - accuracy: 0.8444 - val_loss: 2.0321 - val_accuracy: 0.4563
# Epoch 9/25
# 72/72 [==============================] - 6s 80ms/step - loss: 0.4083 - accuracy: 0.8645 - val_loss: 1.4204 - val_accuracy: 0.6381
# Epoch 10/25
# 72/72 [==============================] - 7s 86ms/step - loss: 0.3959 - accuracy: 0.8654 - val_loss: 1.5014 - val_accuracy: 0.6346
# Epoch 11/25
# 72/72 [==============================] - 8s 103ms/step - loss: 0.3089 - accuracy: 0.8872 - val_loss: 1.3773 - val_accuracy: 0.5507
# Epoch 12/25
# 72/72 [==============================] - 8s 95ms/step - loss: 0.2986 - accuracy: 0.8929 - val_loss: 1.4390 - val_accuracy: 0.5332
# Epoch 13/25
# 72/72 [==============================] - 6s 80ms/step - loss: 0.3223 - accuracy: 0.8842 - val_loss: 7.1425 - val_accuracy: 0.5227
# Epoch 14/25
# 72/72 [==============================] - 7s 93ms/step - loss: 0.2963 - accuracy: 0.8916 - val_loss: 11.6231 - val_accuracy: 0.5070

# %%
history_df = pd.DataFrame(history.history)
history_df[['loss', 'val_loss']].plot()
# Out:
# <Axes: >

# %%
history_df[['accuracy', 'val_accuracy']].plot()
# Out:
# <Axes: >

# %%
model_small_batchnorm.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_7 (Rescaling)     (None, 256, 256, 3)       0
#
#  conv2d_17 (Conv2D)          (None, 254, 254, 64)      1792
#
#  max_pooling2d_17 (MaxPoolin  (None, 127, 127, 64)     0
#  g2D)
#
#  batch_normalization_5 (Batc  (None, 127, 127, 64)     256
#  hNormalization)
#
#  conv2d_18 (Conv2D)          (None, 125, 125, 64)      36928
#
#  max_pooling2d_18 (MaxPoolin  (None, 62, 62, 64)       0
#  g2D)
#
#  batch_normalization_6 (Batc  (None, 62, 62, 64)       256
#  hNormalization)
#
#  conv2d_19 (Conv2D)          (None, 60, 60, 64)        36928
#
#  max_pooling2d_19 (MaxPoolin  (None, 30, 30, 64)       0
#  g2D)
#
#  batch_normalization_7 (Batc  (None, 30, 30, 64)       256
#  hNormalization)
#
#  flatten_4 (Flatten)         (None, 57600)             0
#
#  dense_8 (Dense)             (None, 128)               7372928
#
#  dense_9 (Dense)             (None, 3)                 387
#
#  softmax_4 (Softmax)         (None, 3)                 0
#
# =================================================================
# Total params: 7,449,731
# Trainable params: 7,449,347
# Non-trainable params: 384
# _________________________________________________________________

# %%
test_preds = model_small_batchnorm.predict(val_ds)
test_labels = np.concatenate([y for x,y in val_ds], axis=0)
test_preds_argmax = test_preds.argmax(axis=1)

nn_clf_report = classification_report(test_labels, test_preds_argmax, target_names = class_names)
print(nn_clf_report)

nn_cm = confusion_matrix(test_labels, test_preds_argmax)
nn_cm_disp = ConfusionMatrixDisplay(nn_cm, display_labels = class_names)
nn_cm_disp.plot(xticks_rotation=-90)
# Out:
# 18/18 [==============================] - 1s 28ms/step
#               precision    recall  f1-score   support
#
#      battery       0.59      0.73      0.66       180
#        paper       0.86      0.46      0.60       216
#      plastic       0.57      0.76      0.65       176
#
#     accuracy                           0.64       572
#    macro avg       0.67      0.65      0.64       572
# weighted avg       0.69      0.64      0.63       572

# %% [markdown]
# ## TODO:
# * improve performance
# * the batchnorm fricked with the performance too much
# * all 12 classes
# * conclusion
# * -> transfer learning
